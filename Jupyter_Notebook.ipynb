# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Isioma Nwabineli**

# %% [markdown]
# *I am interested in Data science because data is king!!!*

# %% [markdown]
# ### The code below will execute a simple multiplication of numbers

# %%
3*5*42
# Out:
# 630

# %% [markdown]
# ~~strikethrough~~
#
# 1. one
# 2. two
# 3. three
#
# * one
# * two
# * three
#
# > "Last last, na everybody go chop breakfast"
#
# Horizontal rule
# ___
#
# | Shake  | the   | table |
# | ----   | :---: | ----: |
# | Un     | deux  | trois |
# | quatre | cinq  | six   |
# | sept   | huit  | neuf  |
